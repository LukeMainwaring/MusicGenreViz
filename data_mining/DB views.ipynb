# %% [markdown]
# Imports

# %%
import ast
import json
import pandas as pd
import numpy as np

import pymysql
import pymysql.cursors

# %% [markdown]
# Connect to db

# %%
# Connect to the database
connection = pymysql.connect(host='cis550-2.cmxt8otwhjqc.us-east-2.rds.amazonaws.com',
                             db='cis550',
                             user='cis550',
                             password='cis550eklh',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

# %%
# run this box after you are done with the operations
connection.close()

# %%
query = '''
CREATE VIEW genre_by_year AS (
    SELECT
        ar.year AS year,
        COUNT(*) AS num_genres
    FROM artist_rank ar
    NATURAL JOIN artist_genre ag
    GROUP BY
        year
    ORDER BY 
        year
)
;
'''

with connection.cursor() as cursor:
    cursor.execute(query)
    result = cursor.fetchall()
    for x in result:
        print(x)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-86-c09acbfcb99e> in <module>()
#      15
#      16 with connection.cursor() as cursor:
# ---> 17     cursor.execute(query)
#      18     result = cursor.fetchall()
#      19     for x in result:
#
# ~/.virtualenvs/ds/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     163         query = self.mogrify(query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#     167         return result
#
# ~/.virtualenvs/ds/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     319         conn = self._get_db()
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ...

# %%
query = '''
SELECT * FROM genre_by_year
;
'''

with connection.cursor() as cursor:
    cursor.execute(query)
    result = cursor.fetchall()
    for x in result:
        print(x)
# Out:
# {'year': 1959, 'num_genres': 13224}
# {'year': 1960, 'num_genres': 23374}
# {'year': 1961, 'num_genres': 20752}
# {'year': 1962, 'num_genres': 21628}
# {'year': 1963, 'num_genres': 21872}
# {'year': 1964, 'num_genres': 23820}
# {'year': 1965, 'num_genres': 26505}
# {'year': 1966, 'num_genres': 26283}
# {'year': 1967, 'num_genres': 25296}
# {'year': 1968, 'num_genres': 23144}
# {'year': 1969, 'num_genres': 23755}
# {'year': 1970, 'num_genres': 24484}
# {'year': 1971, 'num_genres': 25156}
# {'year': 1972, 'num_genres': 27869}
# {'year': 1973, 'num_genres': 27610}
# {'year': 1974, 'num_genres': 27943}
# {'year': 1975, 'num_genres': 24357}
# {'year': 1976, 'num_genres': 25591}
# {'year': 1977, 'num_genres': 24278}
# {'year': 1978, 'num_genres': 25084}
# {'year': 1979, 'num_genres': 22695}
# {'year': 1980, 'num_genres': 27819}
# {'year': 1981, 'num_genres': 26461}
# {'year': 1982, 'num_genres': 25200}
# {'year': 1983, 'num_genres': 26229}
# {'year': 1984, 'num_genres': 25888}
# ...

# %%
query = '''
CREATE VIEW genre_by_city AS (
    SELECT
        c.city_name AS city_name,
        COUNT(*) AS num_genres
    FROM artist_city ac
    NATURAL JOIN artist_genre ag
    NATURAL JOIN city c
    GROUP BY
        city_id
    ORDER BY 
        city_id
)
;
'''

with connection.cursor() as cursor:
    cursor.execute(query)
    result = cursor.fetchall()
    for x in result:
        print(x)
# Out:
# {'city_id': 0, 'num_genres': 416}
# {'city_id': 1, 'num_genres': 268}
# {'city_id': 2, 'num_genres': 203}
# {'city_id': 3, 'num_genres': 318}
# {'city_id': 4, 'num_genres': 209}
# {'city_id': 5, 'num_genres': 647}
# {'city_id': 6, 'num_genres': 50}
# {'city_id': 7, 'num_genres': 339}
# {'city_id': 8, 'num_genres': 375}
# {'city_id': 9, 'num_genres': 955}
# {'city_id': 10, 'num_genres': 1072}
# {'city_id': 11, 'num_genres': 179}
# {'city_id': 12, 'num_genres': 603}
# {'city_id': 13, 'num_genres': 209}
# {'city_id': 14, 'num_genres': 36}
# {'city_id': 15, 'num_genres': 613}
# {'city_id': 16, 'num_genres': 505}
# {'city_id': 17, 'num_genres': 692}
# {'city_id': 18, 'num_genres': 597}
# {'city_id': 19, 'num_genres': 450}
# {'city_id': 20, 'num_genres': 809}
# {'city_id': 21, 'num_genres': 686}
# {'city_id': 22, 'num_genres': 816}
# {'city_id': 23, 'num_genres': 398}
# {'city_id': 24, 'num_genres': 261}
# {'city_id': 25, 'num_genres': 920}
# {'city_id': 26, 'num_genres': 171}
# ...

# %%
query = '''
SELECT 
    ag.genre, 
    COUNT(*)/(SELECT num_genres FROM genre_by_city WHERE city_id = {city_id}) AS percent
FROM artist_city ac
NATURAL JOIN artist_genre ag
NATURAL JOIN city c
WHERE city_id = {city_id}
GROUP BY
    genre
ORDER BY 
    percent DESC
LIMIT 10
;
'''.format(city_id='0')


with connection.cursor() as cursor:
    cursor.execute(query)
    result = cursor.fetchall()
    for x in result:
        print(x)
# Out:
# {'genre': 'latin', 'percent': Decimal('0.1779')}
# {'genre': 'tropical', 'percent': Decimal('0.1635')}
# {'genre': 'reggaeton flow', 'percent': Decimal('0.1058')}
# {'genre': 'reggaeton', 'percent': Decimal('0.0986')}
# {'genre': 'latin hip hop', 'percent': Decimal('0.0962')}
# {'genre': 'latin pop', 'percent': Decimal('0.0769')}
# {'genre': 'trap latino', 'percent': Decimal('0.0625')}
# {'genre': 'cumbia', 'percent': Decimal('0.0505')}
# {'genre': 'pop', 'percent': Decimal('0.0216')}
# {'genre': 'salsa', 'percent': Decimal('0.0192')}

# %%
query = '''
    SELECT
        ac.city_id AS city_id,
        COUNT(*) AS num_genres
    FROM artist_city ac
    NATURAL JOIN artist_genre ag
    GROUP BY
        city_id
    ORDER BY 
        city_id;
'''


with connection.cursor() as cursor:
    cursor.execute(query)
    result = cursor.fetchall()
    for x in result:
        print(x)
# Out:
# {'city_id': 0, 'num_genres': 416}
# {'city_id': 1, 'num_genres': 268}
# {'city_id': 2, 'num_genres': 203}
# {'city_id': 3, 'num_genres': 318}
# {'city_id': 4, 'num_genres': 209}
# {'city_id': 5, 'num_genres': 647}
# {'city_id': 6, 'num_genres': 50}
# {'city_id': 7, 'num_genres': 339}
# {'city_id': 8, 'num_genres': 375}
# {'city_id': 9, 'num_genres': 955}
# {'city_id': 10, 'num_genres': 1072}
# {'city_id': 11, 'num_genres': 179}
# {'city_id': 12, 'num_genres': 603}
# {'city_id': 13, 'num_genres': 209}
# {'city_id': 14, 'num_genres': 36}
# {'city_id': 15, 'num_genres': 613}
# {'city_id': 16, 'num_genres': 505}
# {'city_id': 17, 'num_genres': 692}
# {'city_id': 18, 'num_genres': 597}
# {'city_id': 19, 'num_genres': 450}
# {'city_id': 20, 'num_genres': 809}
# {'city_id': 21, 'num_genres': 686}
# {'city_id': 22, 'num_genres': 816}
# {'city_id': 23, 'num_genres': 398}
# {'city_id': 24, 'num_genres': 261}
# {'city_id': 25, 'num_genres': 920}
# {'city_id': 26, 'num_genres': 171}
# ...

# %%
query = '''
SELECT * FROM genre_by_city
'''


with connection.cursor() as cursor:
    cursor.execute(query)
    result = cursor.fetchall()
    for x in result:
        print(x)
# Out:
# {'city_id': 0, 'num_genres': 416}
# {'city_id': 1, 'num_genres': 268}
# {'city_id': 2, 'num_genres': 203}
# {'city_id': 3, 'num_genres': 318}
# {'city_id': 4, 'num_genres': 209}
# {'city_id': 5, 'num_genres': 647}
# {'city_id': 6, 'num_genres': 50}
# {'city_id': 7, 'num_genres': 339}
# {'city_id': 8, 'num_genres': 375}
# {'city_id': 9, 'num_genres': 955}
# {'city_id': 10, 'num_genres': 1072}
# {'city_id': 11, 'num_genres': 179}
# {'city_id': 12, 'num_genres': 603}
# {'city_id': 13, 'num_genres': 209}
# {'city_id': 14, 'num_genres': 36}
# {'city_id': 15, 'num_genres': 613}
# {'city_id': 16, 'num_genres': 505}
# {'city_id': 17, 'num_genres': 692}
# {'city_id': 18, 'num_genres': 597}
# {'city_id': 19, 'num_genres': 450}
# {'city_id': 20, 'num_genres': 809}
# {'city_id': 21, 'num_genres': 686}
# {'city_id': 22, 'num_genres': 816}
# {'city_id': 23, 'num_genres': 398}
# {'city_id': 24, 'num_genres': 261}
# {'city_id': 25, 'num_genres': 920}
# {'city_id': 26, 'num_genres': 171}
# ...

# %%
[{'genre': x['genre'], 'percent': round(float(x['percent']) * 100, 2)} for x in result]
# Out:
# [{'genre': 'latin', 'percent': 17.79},
#  {'genre': 'tropical', 'percent': 16.35},
#  {'genre': 'reggaeton flow', 'percent': 10.58},
#  {'genre': 'reggaeton', 'percent': 9.86},
#  {'genre': 'latin hip hop', 'percent': 9.62},
#  {'genre': 'latin pop', 'percent': 7.69},
#  {'genre': 'trap latino', 'percent': 6.25},
#  {'genre': 'cumbia', 'percent': 5.05},
#  {'genre': 'pop', 'percent': 2.16},
#  {'genre': 'salsa', 'percent': 1.92}]

# %%
connection.commit()

# %%
years = [{'year': 1982}, {'year': 1984}, {'year': 1985}, {'year': 1987}, {'year': 1990}, {'year': 1980}, {'year': 1981}, {'year': 2012}, {'year': 2013}, {'year': 2014}, {'year': 2015}, {'year': 2016}, {'year': 2017}, {'year': 2011}, {'year': 2005}, {'year': 1989}, {'year': 1994}, {'year': 1995}, {'year': 1996}, {'year': 1997}, {'year': 1999}, {'year': 2006}, {'year': 2007}, {'year': 2008}, {'year': 2009}, {'year': 2010}, {'year': 1986}, {'year': 2000}, {'year': 2002}, {'year': 1977}, {'year': 1964}, {'year': 1965}, {'year': 1993}, {'year': 1992}, {'year': 1998}, {'year': 2001}, {'year': 2018}, {'year': 2003}, {'year': 2004}, {'year': 1966}, {'year': 1959}, {'year': 1961}, {'year': 1970}, {'year': 1971}, {'year': 1972}, {'year': 1967}, {'year': 1968}, {'year': 1988}, {'year': 1991}, {'year': 1975}, {'year': 1976}, {'year': 1978}, {'year': 1979}, {'year': 1960}, {'year': 1963}, {'year': 1974}, {'year': 1983}, {'year': 1973}, {'year': 1962}, {'year': 1969}]

# %%
# Out:
# [1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018]

# %%
test = [{'year': 1959, 'genres': [{'genre': 'brill building pop', 'percent': 6.68}, {'genre': 'christmas', 'percent': 6.58}, {'genre': 'adult standards', 'percent': 6.57}, {'genre': 'rock-and-roll', 'percent': 6.5}, {'genre': 'rockabilly', 'percent': 5.25}, {'genre': 'doo-wop', 'percent': 4.81}, {'genre': 'lounge', 'percent': 4.38}, {'genre': 'jazz blues', 'percent': 3.15}, {'genre': 'soul', 'percent': 2.79}, {'genre': 'nashville sound', 'percent': 2.45}]}, {'year': 1960, 'genres': [{'genre': 'christmas', 'percent': 6.9}, {'genre': 'adult standards', 'percent': 6.78}, {'genre': 'brill building pop', 'percent': 6.66}, {'genre': 'rock-and-roll', 'percent': 6.39}, {'genre': 'rockabilly', 'percent': 5.6}, {'genre': 'lounge', 'percent': 4.3}, {'genre': 'doo-wop', 'percent': 4.16}, {'genre': 'jazz blues', 'percent': 2.82}, {'genre': 'nashville sound', 'percent': 2.76}, {'genre': 'soul', 'percent': 2.61}]}, {'year': 1961, 'genres': [{'genre': 'brill building pop', 'percent': 7.26}, {'genre': 'adult standards', 'percent': 6.73}, {'genre': 'christmas', 'percent': 6.68}, {'genre': 'rock-and-roll', 'percent': 5.85}, {'genre': 'rockabilly', 'percent': 5.11}, {'genre': 'doo-wop', 'percent': 4.68}, {'genre': 'lounge', 'percent': 3.77}, {'genre': 'soul', 'percent': 2.96}, {'genre': 'southern soul', 'percent': 2.83}, {'genre': 'jazz blues', 'percent': 2.79}]}, {'year': 1962, 'genres': [{'genre': 'brill building pop', 'percent': 7.34}, {'genre': 'adult standards', 'percent': 6.55}, {'genre': 'christmas', 'percent': 6.55}, {'genre': 'rock-and-roll', 'percent': 5.26}, {'genre': 'rockabilly', 'percent': 4.2}, {'genre': 'lounge', 'percent': 3.67}, {'genre': 'doo-wop', 'percent': 3.38}, {'genre': 'soul', 'percent': 3.1}, {'genre': 'jazz blues', 'percent': 2.95}, {'genre': 'chicago soul', 'percent': 2.86}]}, {'year': 1963, 'genres': [{'genre': 'brill building pop', 'percent': 7.66}, {'genre': 'adult standards', 'percent': 6.17}, {'genre': 'christmas', 'percent': 5.89}, {'genre': 'rock-and-roll', 'percent': 4.52}, {'genre': 'chicago soul', 'percent': 3.64}, {'genre': 'rockabilly', 'percent': 3.6}, {'genre': 'motown', 'percent': 3.31}, {'genre': 'doo-wop', 'percent': 3.27}, {'genre': 'soul', 'percent': 3.18}, {'genre': 'folk rock', 'percent': 3.11}]}, {'year': 1964, 'genres': [{'genre': 'brill building pop', 'percent': 6.95}, {'genre': 'adult standards', 'percent': 5.28}, {'genre': 'christmas', 'percent': 5.26}, {'genre': 'rock-and-roll', 'percent': 4.33}, {'genre': 'folk rock', 'percent': 3.83}, {'genre': 'soul', 'percent': 3.54}, {'genre': 'chicago soul', 'percent': 3.3}, {'genre': 'merseybeat', 'percent': 3.22}, {'genre': 'motown', 'percent': 3.18}, {'genre': 'rockabilly', 'percent': 3.14}]}, {'year': 1965, 'genres': [{'genre': 'brill building pop', 'percent': 6.33}, {'genre': 'folk rock', 'percent': 4.95}, {'genre': 'christmas', 'percent': 4.8}, {'genre': 'adult standards', 'percent': 4.74}, {'genre': 'rock-and-roll', 'percent': 4.03}, {'genre': 'bubblegum pop', 'percent': 3.71}, {'genre': 'merseybeat', 'percent': 3.49}, {'genre': 'chicago soul', 'percent': 2.9}, {'genre': 'mellow gold', 'percent': 2.67}, {'genre': 'motown', 'percent': 2.58}]}, {'year': 1966, 'genres': [{'genre': 'brill building pop', 'percent': 5.86}, {'genre': 'folk rock', 'percent': 5.0}, {'genre': 'adult standards', 'percent': 4.15}, {'genre': 'bubblegum pop', 'percent': 4.13}, {'genre': 'christmas', 'percent': 3.99}, {'genre': 'rock-and-roll', 'percent': 3.83}, {'genre': 'mellow gold', 'percent': 3.09}, {'genre': 'merseybeat', 'percent': 3.09}, {'genre': 'motown', 'percent': 2.95}, {'genre': 'soul', 'percent': 2.7}]}, {'year': 1967, 'genres': [{'genre': 'brill building pop', 'percent': 5.46}, {'genre': 'folk rock', 'percent': 4.87}, {'genre': 'adult standards', 'percent': 3.86}, {'genre': 'bubblegum pop', 'percent': 3.82}, {'genre': 'christmas', 'percent': 3.63}, {'genre': 'motown', 'percent': 3.47}, {'genre': 'mellow gold', 'percent': 3.21}, {'genre': 'rock-and-roll', 'percent': 3.05}, {'genre': 'soul', 'percent': 3.01}, {'genre': 'chicago soul', 'percent': 3.0}]}, {'year': 1968, 'genres': [{'genre': 'brill building pop', 'percent': 4.76}, {'genre': 'folk rock', 'percent': 3.94}, {'genre': 'soul', 'percent': 3.8}, {'genre': 'motown', 'percent': 3.62}, {'genre': 'adult standards', 'percent': 3.34}, {'genre': 'christmas', 'percent': 3.26}, {'genre': 'southern soul', 'percent': 3.25}, {'genre': 'memphis soul', 'percent': 3.19}, {'genre': 'chicago soul', 'percent': 3.18}, {'genre': 'soul blues', 'percent': 3.16}]}, {'year': 1969, 'genres': [{'genre': 'brill building pop', 'percent': 4.79}, {'genre': 'folk rock', 'percent': 4.03}, {'genre': 'motown', 'percent': 3.96}, {'genre': 'soul', 'percent': 3.86}, {'genre': 'soul blues', 'percent': 3.36}, {'genre': 'southern soul', 'percent': 3.3}, {'genre': 'bubblegum pop', 'percent': 3.21}, {'genre': 'memphis soul', 'percent': 3.16}, {'genre': 'adult standards', 'percent': 3.1}, {'genre': 'chicago soul', 'percent': 3.09}]}, {'year': 1970, 'genres': [{'genre': 'mellow gold', 'percent': 4.18}, {'genre': 'folk rock', 'percent': 3.96}, {'genre': 'motown', 'percent': 3.74}, {'genre': 'soul', 'percent': 3.54}, {'genre': 'brill building pop', 'percent': 3.26}, {'genre': 'adult standards', 'percent': 3.17}, {'genre': 'soul blues', 'percent': 3.07}, {'genre': 'soft rock', 'percent': 3.03}, {'genre': 'memphis soul', 'percent': 3.01}, {'genre': 'classic rock', 'percent': 3.01}]}, {'year': 1971, 'genres': [{'genre': 'mellow gold', 'percent': 4.4}, {'genre': 'folk rock', 'percent': 3.88}, {'genre': 'soft rock', 'percent': 3.36}, {'genre': 'soul', 'percent': 3.34}, {'genre': 'adult standards', 'percent': 3.2}, {'genre': 'motown', 'percent': 3.2}, {'genre': 'memphis soul', 'percent': 2.97}, {'genre': 'southern soul', 'percent': 2.96}, {'genre': 'classic rock', 'percent': 2.96}, {'genre': 'chicago soul', 'percent': 2.9}]}, {'year': 1972, 'genres': [{'genre': 'mellow gold', 'percent': 4.7}, {'genre': 'folk rock', 'percent': 3.95}, {'genre': 'soft rock', 'percent': 3.66}, {'genre': 'classic rock', 'percent': 3.44}, {'genre': 'soul', 'percent': 3.2}, {'genre': 'rock', 'percent': 3.13}, {'genre': 'memphis soul', 'percent': 3.1}, {'genre': 'singer-songwriter', 'percent': 3.08}, {'genre': 'southern soul', 'percent': 3.04}, {'genre': 'soul blues', 'percent': 2.94}]}, {'year': 1973, 'genres': [{'genre': 'mellow gold', 'percent': 4.57}, {'genre': 'classic funk rock', 'percent': 3.89}, {'genre': 'soul', 'percent': 3.84}, {'genre': 'soft rock', 'percent': 3.53}, {'genre': 'folk rock', 'percent': 3.52}, {'genre': 'funk', 'percent': 3.51}, {'genre': 'motown', 'percent': 3.51}, {'genre': 'memphis soul', 'percent': 3.11}, {'genre': 'southern soul', 'percent': 3.07}, {'genre': 'disco', 'percent': 2.93}]}, {'year': 1974, 'genres': [{'genre': 'mellow gold', 'percent': 4.46}, {'genre': 'classic funk rock', 'percent': 4.31}, {'genre': 'disco', 'percent': 3.79}, {'genre': 'soul', 'percent': 3.79}, {'genre': 'motown', 'percent': 3.77}, {'genre': 'funk', 'percent': 3.64}, {'genre': 'soft rock', 'percent': 3.6}, {'genre': 'quiet storm', 'percent': 3.32}, {'genre': 'folk rock', 'percent': 3.28}, {'genre': 'memphis soul', 'percent': 2.83}]}, {'year': 1975, 'genres': [{'genre': 'mellow gold', 'percent': 5.57}, {'genre': 'soft rock', 'percent': 5.14}, {'genre': 'folk rock', 'percent': 3.95}, {'genre': 'disco', 'percent': 3.56}, {'genre': 'classic rock', 'percent': 3.44}, {'genre': 'rock', 'percent': 3.25}, {'genre': 'classic funk rock', 'percent': 3.08}, {'genre': 'album rock', 'percent': 3.03}, {'genre': 'adult standards', 'percent': 2.86}, {'genre': 'singer-songwriter', 'percent': 2.69}]}, {'year': 1976, 'genres': [{'genre': 'mellow gold', 'percent': 5.65}, {'genre': 'soft rock', 'percent': 5.33}, {'genre': 'disco', 'percent': 4.88}, {'genre': 'rock', 'percent': 4.12}, {'genre': 'album rock', 'percent': 4.12}, {'genre': 'classic rock', 'percent': 4.07}, {'genre': 'classic funk rock', 'percent': 3.73}, {'genre': 'folk rock', 'percent': 3.64}, {'genre': 'motown', 'percent': 3.12}, {'genre': 'adult standards', 'percent': 2.95}]}, {'year': 1977, 'genres': [{'genre': 'soft rock', 'percent': 6.93}, {'genre': 'mellow gold', 'percent': 6.85}, {'genre': 'disco', 'percent': 4.32}, {'genre': 'classic rock', 'percent': 4.31}, {'genre': 'album rock', 'percent': 4.3}, {'genre': 'folk rock', 'percent': 4.25}, {'genre': 'rock', 'percent': 4.04}, {'genre': 'adult standards', 'percent': 3.43}, {'genre': 'classic funk rock', 'percent': 2.95}, {'genre': 'motown', 'percent': 2.83}]}, {'year': 1978, 'genres': [{'genre': 'mellow gold', 'percent': 7.73}, {'genre': 'soft rock', 'percent': 7.7}, {'genre': 'album rock', 'percent': 4.97}, {'genre': 'rock', 'percent': 4.85}, {'genre': 'classic rock', 'percent': 4.56}, {'genre': 'folk rock', 'percent': 4.27}, {'genre': 'disco', 'percent': 4.05}, {'genre': 'adult standards', 'percent': 3.19}, {'genre': 'singer-songwriter', 'percent': 3.16}, {'genre': 'classic funk rock', 'percent': 2.5}]}, {'year': 1979, 'genres': [{'genre': 'soft rock', 'percent': 7.16}, {'genre': 'mellow gold', 'percent': 7.12}, {'genre': 'album rock', 'percent': 5.15}, {'genre': 'rock', 'percent': 4.81}, {'genre': 'classic rock', 'percent': 4.66}, {'genre': 'disco', 'percent': 4.19}, {'genre': 'folk rock', 'percent': 3.65}, {'genre': 'art rock', 'percent': 2.81}, {'genre': 'singer-songwriter', 'percent': 2.53}, {'genre': 'classic funk rock', 'percent': 2.51}]}, {'year': 1980, 'genres': [{'genre': 'mellow gold', 'percent': 7.06}, {'genre': 'soft rock', 'percent': 6.92}, {'genre': 'album rock', 'percent': 4.53}, {'genre': 'rock', 'percent': 4.22}, {'genre': 'classic rock', 'percent': 3.97}, {'genre': 'folk rock', 'percent': 3.71}, {'genre': 'disco', 'percent': 3.33}, {'genre': 'adult standards', 'percent': 3.14}, {'genre': 'quiet storm', 'percent': 2.68}, {'genre': 'classic funk rock', 'percent': 2.45}]}, {'year': 1981, 'genres': [{'genre': 'soft rock', 'percent': 7.34}, {'genre': 'mellow gold', 'percent': 7.2}, {'genre': 'album rock', 'percent': 4.71}, {'genre': 'rock', 'percent': 4.44}, {'genre': 'classic rock', 'percent': 4.23}, {'genre': 'folk rock', 'percent': 3.46}, {'genre': 'disco', 'percent': 3.33}, {'genre': 'adult standards', 'percent': 2.98}, {'genre': 'classic funk rock', 'percent': 2.62}, {'genre': 'quiet storm', 'percent': 2.57}]}, {'year': 1982, 'genres': [{'genre': 'soft rock', 'percent': 7.29}, {'genre': 'mellow gold', 'percent': 6.85}, {'genre': 'album rock', 'percent': 5.36}, {'genre': 'rock', 'percent': 5.02}, {'genre': 'classic rock', 'percent': 3.7}, {'genre': 'new wave pop', 'percent': 3.2}, {'genre': 'disco', 'percent': 3.13}, {'genre': 'folk rock', 'percent': 3.05}, {'genre': 'adult standards', 'percent': 2.76}, {'genre': 'quiet storm', 'percent': 2.63}]}, {'year': 1983, 'genres': [{'genre': 'soft rock', 'percent': 7.26}, {'genre': 'mellow gold', 'percent': 6.94}, {'genre': 'rock', 'percent': 5.23}, {'genre': 'album rock', 'percent': 5.09}, {'genre': 'new wave pop', 'percent': 4.41}, {'genre': 'classic rock', 'percent': 3.69}, {'genre': 'dance rock', 'percent': 3.66}, {'genre': 'new wave', 'percent': 2.94}, {'genre': 'art rock', 'percent': 2.79}, {'genre': 'new romantic', 'percent': 2.78}]}, {'year': 1984, 'genres': [{'genre': 'soft rock', 'percent': 7.57}, {'genre': 'mellow gold', 'percent': 7.07}, {'genre': 'rock', 'percent': 5.38}, {'genre': 'new wave pop', 'percent': 5.28}, {'genre': 'album rock', 'percent': 5.01}, {'genre': 'dance rock', 'percent': 3.7}, {'genre': 'classic rock', 'percent': 3.63}, {'genre': 'disco', 'percent': 3.52}, {'genre': 'new romantic', 'percent': 3.46}, {'genre': 'new wave', 'percent': 2.97}]}, {'year': 1985, 'genres': [{'genre': 'soft rock', 'percent': 6.83}, {'genre': 'mellow gold', 'percent': 6.27}, {'genre': 'new wave pop', 'percent': 5.5}, {'genre': 'rock', 'percent': 5.0}, {'genre': 'album rock', 'percent': 4.43}, {'genre': 'dance rock', 'percent': 4.28}, {'genre': 'new romantic', 'percent': 3.66}, {'genre': 'new wave', 'percent': 3.47}, {'genre': 'disco', 'percent': 3.38}, {'genre': 'classic rock', 'percent': 3.32}]}, {'year': 1986, 'genres': [{'genre': 'soft rock', 'percent': 6.27}, {'genre': 'mellow gold', 'percent': 6.03}, {'genre': 'rock', 'percent': 4.97}, {'genre': 'new wave pop', 'percent': 4.95}, {'genre': 'album rock', 'percent': 4.81}, {'genre': 'dance rock', 'percent': 3.92}, {'genre': 'new romantic', 'percent': 3.61}, {'genre': 'classic rock', 'percent': 3.61}, {'genre': 'new wave', 'percent': 3.5}, {'genre': 'disco', 'percent': 2.71}]}, {'year': 1987, 'genres': [{'genre': 'soft rock', 'percent': 6.1}, {'genre': 'mellow gold', 'percent': 5.62}, {'genre': 'rock', 'percent': 5.33}, {'genre': 'new wave pop', 'percent': 5.15}, {'genre': 'album rock', 'percent': 4.87}, {'genre': 'dance rock', 'percent': 3.83}, {'genre': 'new romantic', 'percent': 3.37}, {'genre': 'classic rock', 'percent': 3.19}, {'genre': 'new wave', 'percent': 2.68}, {'genre': 'quiet storm', 'percent': 2.48}]}, {'year': 1988, 'genres': [{'genre': 'new wave pop', 'percent': 5.91}, {'genre': 'rock', 'percent': 5.25}, {'genre': 'soft rock', 'percent': 5.19}, {'genre': 'mellow gold', 'percent': 5.19}, {'genre': 'album rock', 'percent': 4.76}, {'genre': 'dance rock', 'percent': 3.94}, {'genre': 'classic rock', 'percent': 3.51}, {'genre': 'new romantic', 'percent': 3.29}, {'genre': 'dance pop', 'percent': 2.82}, {'genre': 'new wave', 'percent': 2.74}]}, {'year': 1989, 'genres': [{'genre': 'new wave pop', 'percent': 5.87}, {'genre': 'rock', 'percent': 5.46}, {'genre': 'album rock', 'percent': 4.92}, {'genre': 'soft rock', 'percent': 4.92}, {'genre': 'mellow gold', 'percent': 4.53}, {'genre': 'classic rock', 'percent': 3.34}, {'genre': 'hard rock', 'percent': 3.04}, {'genre': 'dance pop', 'percent': 2.97}, {'genre': 'dance rock', 'percent': 2.82}, {'genre': 'new romantic', 'percent': 2.61}]}, {'year': 1990, 'genres': [{'genre': 'rock', 'percent': 4.71}, {'genre': 'soft rock', 'percent': 4.54}, {'genre': 'album rock', 'percent': 4.46}, {'genre': 'new wave pop', 'percent': 4.21}, {'genre': 'mellow gold', 'percent': 4.17}, {'genre': 'hard rock', 'percent': 3.08}, {'genre': 'dance pop', 'percent': 3.0}, {'genre': 'classic rock', 'percent': 2.87}, {'genre': 'urban contemporary', 'percent': 2.8}, {'genre': 'quiet storm', 'percent': 2.41}]}, {'year': 1991, 'genres': [{'genre': 'rock', 'percent': 4.66}, {'genre': 'album rock', 'percent': 4.21}, {'genre': 'urban contemporary', 'percent': 4.05}, {'genre': 'mellow gold', 'percent': 3.72}, {'genre': 'soft rock', 'percent': 3.65}, {'genre': 'new wave pop', 'percent': 3.32}, {'genre': 'dance pop', 'percent': 3.05}, {'genre': 'new jack swing', 'percent': 2.98}, {'genre': 'hard rock', 'percent': 2.94}, {'genre': 'quiet storm', 'percent': 2.9}]}, {'year': 1992, 'genres': [{'genre': 'urban contemporary', 'percent': 4.32}, {'genre': 'rock', 'percent': 4.25}, {'genre': 'new jack swing', 'percent': 4.23}, {'genre': 'dance pop', 'percent': 3.59}, {'genre': 'r&b', 'percent': 3.34}, {'genre': 'album rock', 'percent': 3.27}, {'genre': 'soft rock', 'percent': 3.16}, {'genre': 'mellow gold', 'percent': 3.01}, {'genre': 'pop christmas', 'percent': 2.99}, {'genre': 'new wave pop', 'percent': 2.77}]}, {'year': 1993, 'genres': [{'genre': 'urban contemporary', 'percent': 4.34}, {'genre': 'new jack swing', 'percent': 4.14}, {'genre': 'r&b', 'percent': 3.99}, {'genre': 'dance pop', 'percent': 3.53}, {'genre': 'quiet storm', 'percent': 3.23}, {'genre': 'rock', 'percent': 3.23}, {'genre': 'hip pop', 'percent': 3.15}, {'genre': 'pop christmas', 'percent': 2.99}, {'genre': 'soul christmas', 'percent': 2.94}, {'genre': 'neo soul', 'percent': 2.81}]}, {'year': 1994, 'genres': [{'genre': 'urban contemporary', 'percent': 3.78}, {'genre': 'hip pop', 'percent': 3.34}, {'genre': 'r&b', 'percent': 3.28}, {'genre': 'new jack swing', 'percent': 3.26}, {'genre': 'rock', 'percent': 3.08}, {'genre': 'dance pop', 'percent': 2.98}, {'genre': 'pop christmas', 'percent': 2.91}, {'genre': 'hip hop', 'percent': 2.78}, {'genre': 'neo soul', 'percent': 2.75}, {'genre': 'pop rock', 'percent': 2.65}]}, {'year': 1995, 'genres': [{'genre': 'urban contemporary', 'percent': 4.19}, {'genre': 'new jack swing', 'percent': 3.8}, {'genre': 'r&b', 'percent': 3.77}, {'genre': 'hip pop', 'percent': 3.48}, {'genre': 'pop christmas', 'percent': 3.45}, {'genre': 'dance pop', 'percent': 3.24}, {'genre': 'pop rock', 'percent': 3.14}, {'genre': 'hip hop', 'percent': 3.06}, {'genre': 'neo soul', 'percent': 2.91}, {'genre': 'rap', 'percent': 2.81}]}, {'year': 1996, 'genres': [{'genre': 'urban contemporary', 'percent': 4.91}, {'genre': 'pop christmas', 'percent': 4.48}, {'genre': 'dance pop', 'percent': 4.32}, {'genre': 'new jack swing', 'percent': 4.12}, {'genre': 'r&b', 'percent': 4.09}, {'genre': 'hip pop', 'percent': 4.02}, {'genre': 'neo soul', 'percent': 3.32}, {'genre': 'hip hop', 'percent': 3.18}, {'genre': 'pop rock', 'percent': 3.16}, {'genre': 'rap', 'percent': 2.98}]}, {'year': 1997, 'genres': [{'genre': 'urban contemporary', 'percent': 4.53}, {'genre': 'r&b', 'percent': 4.48}, {'genre': 'hip pop', 'percent': 4.47}, {'genre': 'dance pop', 'percent': 4.36}, {'genre': 'pop christmas', 'percent': 4.06}, {'genre': 'new jack swing', 'percent': 3.88}, {'genre': 'rap', 'percent': 3.36}, {'genre': 'hip hop', 'percent': 3.34}, {'genre': 'pop rap', 'percent': 3.29}, {'genre': 'neo soul', 'percent': 3.16}]}, {'year': 1998, 'genres': [{'genre': 'pop christmas', 'percent': 4.65}, {'genre': 'pop rap', 'percent': 4.07}, {'genre': 'dance pop', 'percent': 4.02}, {'genre': 'hip pop', 'percent': 3.98}, {'genre': 'hip hop', 'percent': 3.42}, {'genre': 'rap', 'percent': 3.42}, {'genre': 'urban contemporary', 'percent': 3.42}, {'genre': 'r&b', 'percent': 3.29}, {'genre': 'southern hip hop', 'percent': 2.84}, {'genre': 'gangster rap', 'percent': 2.73}]}, {'year': 1999, 'genres': [{'genre': 'pop christmas', 'percent': 5.02}, {'genre': 'dance pop', 'percent': 4.84}, {'genre': 'urban contemporary', 'percent': 4.29}, {'genre': 'r&b', 'percent': 3.87}, {'genre': 'hip pop', 'percent': 3.8}, {'genre': 'country', 'percent': 3.63}, {'genre': 'pop rap', 'percent': 3.61}, {'genre': 'contemporary country', 'percent': 3.4}, {'genre': 'country christmas', 'percent': 3.12}, {'genre': 'neo soul', 'percent': 2.98}]}, {'year': 2000, 'genres': [{'genre': 'dance pop', 'percent': 4.84}, {'genre': 'pop christmas', 'percent': 4.64}, {'genre': 'urban contemporary', 'percent': 4.32}, {'genre': 'hip pop', 'percent': 4.06}, {'genre': 'r&b', 'percent': 3.97}, {'genre': 'country', 'percent': 3.66}, {'genre': 'contemporary country', 'percent': 3.35}, {'genre': 'country christmas', 'percent': 3.34}, {'genre': 'pop rap', 'percent': 3.21}, {'genre': 'country road', 'percent': 2.9}]}, {'year': 2001, 'genres': [{'genre': 'dance pop', 'percent': 5.65}, {'genre': 'urban contemporary', 'percent': 5.17}, {'genre': 'hip pop', 'percent': 5.09}, {'genre': 'pop christmas', 'percent': 4.91}, {'genre': 'r&b', 'percent': 4.81}, {'genre': 'pop rap', 'percent': 4.47}, {'genre': 'hip hop', 'percent': 3.31}, {'genre': 'rap', 'percent': 3.21}, {'genre': 'country', 'percent': 3.09}, {'genre': 'pop', 'percent': 3.05}]}, {'year': 2002, 'genres': [{'genre': 'hip pop', 'percent': 5.2}, {'genre': 'dance pop', 'percent': 5.17}, {'genre': 'pop rap', 'percent': 4.79}, {'genre': 'pop christmas', 'percent': 4.39}, {'genre': 'urban contemporary', 'percent': 4.35}, {'genre': 'r&b', 'percent': 4.32}, {'genre': 'rap', 'percent': 3.68}, {'genre': 'hip hop', 'percent': 3.65}, {'genre': 'southern hip hop', 'percent': 3.07}, {'genre': 'pop', 'percent': 3.03}]}, {'year': 2003, 'genres': [{'genre': 'pop rap', 'percent': 5.5}, {'genre': 'dance pop', 'percent': 5.17}, {'genre': 'r&b', 'percent': 4.33}, {'genre': 'hip pop', 'percent': 4.29}, {'genre': 'urban contemporary', 'percent': 3.99}, {'genre': 'pop christmas', 'percent': 3.96}, {'genre': 'rap', 'percent': 3.77}, {'genre': 'hip hop', 'percent': 3.73}, {'genre': 'southern hip hop', 'percent': 3.32}, {'genre': 'pop', 'percent': 2.85}]}, {'year': 2004, 'genres': [{'genre': 'pop rap', 'percent': 5.78}, {'genre': 'rap', 'percent': 4.59}, {'genre': 'dance pop', 'percent': 4.15}, {'genre': 'hip pop', 'percent': 4.11}, {'genre': 'southern hip hop', 'percent': 4.08}, {'genre': 'hip hop', 'percent': 3.86}, {'genre': 'pop christmas', 'percent': 3.85}, {'genre': 'dirty south rap', 'percent': 3.59}, {'genre': 'r&b', 'percent': 3.43}, {'genre': 'urban contemporary', 'percent': 3.32}]}, {'year': 2005, 'genres': [{'genre': 'pop rap', 'percent': 6.31}, {'genre': 'dance pop', 'percent': 5.23}, {'genre': 'rap', 'percent': 4.84}, {'genre': 'r&b', 'percent': 4.42}, {'genre': 'hip pop', 'percent': 4.18}, {'genre': 'pop christmas', 'percent': 4.14}, {'genre': 'pop', 'percent': 3.96}, {'genre': 'hip hop', 'percent': 3.96}, {'genre': 'southern hip hop', 'percent': 3.86}, {'genre': 'urban contemporary', 'percent': 3.8}]}, {'year': 2006, 'genres': [{'genre': 'pop rap', 'percent': 6.32}, {'genre': 'dance pop', 'percent': 5.35}, {'genre': 'pop christmas', 'percent': 4.36}, {'genre': 'rap', 'percent': 4.33}, {'genre': 'pop', 'percent': 4.18}, {'genre': 'r&b', 'percent': 4.14}, {'genre': 'hip pop', 'percent': 3.88}, {'genre': 'southern hip hop', 'percent': 3.82}, {'genre': 'dirty south rap', 'percent': 3.71}, {'genre': 'urban contemporary', 'percent': 3.34}]}, {'year': 2007, 'genres': [{'genre': 'dance pop', 'percent': 6.46}, {'genre': 'pop rap', 'percent': 6.32}, {'genre': 'pop', 'percent': 5.97}, {'genre': 'r&b', 'percent': 4.82}, {'genre': 'rap', 'percent': 4.71}, {'genre': 'pop christmas', 'percent': 4.36}, {'genre': 'urban contemporary', 'percent': 3.96}, {'genre': 'hip pop', 'percent': 3.87}, {'genre': 'southern hip hop', 'percent': 3.7}, {'genre': 'hip hop', 'percent': 3.2}]}, {'year': 2008, 'genres': [{'genre': 'dance pop', 'percent': 6.88}, {'genre': 'pop', 'percent': 6.74}, {'genre': 'pop rap', 'percent': 6.24}, {'genre': 'pop christmas', 'percent': 5.63}, {'genre': 'r&b', 'percent': 4.7}, {'genre': 'rap', 'percent': 4.23}, {'genre': 'urban contemporary', 'percent': 3.94}, {'genre': 'post-teen pop', 'percent': 3.3}, {'genre': 'hip pop', 'percent': 3.23}, {'genre': 'southern hip hop', 'percent': 3.21}]}, {'year': 2009, 'genres': [{'genre': 'dance pop', 'percent': 7.52}, {'genre': 'pop', 'percent': 7.14}, {'genre': 'pop rap', 'percent': 6.6}, {'genre': 'pop christmas', 'percent': 5.49}, {'genre': 'rap', 'percent': 4.4}, {'genre': 'r&b', 'percent': 4.31}, {'genre': 'post-teen pop', 'percent': 4.23}, {'genre': 'urban contemporary', 'percent': 3.77}, {'genre': 'hip hop', 'percent': 3.15}, {'genre': 'southern hip hop', 'percent': 3.08}]}, {'year': 2010, 'genres': [{'genre': 'dance pop', 'percent': 8.2}, {'genre': 'pop', 'percent': 8.08}, {'genre': 'pop rap', 'percent': 7.6}, {'genre': 'pop christmas', 'percent': 5.28}, {'genre': 'rap', 'percent': 4.82}, {'genre': 'post-teen pop', 'percent': 4.65}, {'genre': 'hip hop', 'percent': 4.02}, {'genre': 'r&b', 'percent': 3.9}, {'genre': 'country', 'percent': 3.26}, {'genre': 'contemporary country', 'percent': 3.26}]}, {'year': 2011, 'genres': [{'genre': 'pop', 'percent': 8.89}, {'genre': 'dance pop', 'percent': 7.9}, {'genre': 'pop rap', 'percent': 7.29}, {'genre': 'pop christmas', 'percent': 5.63}, {'genre': 'rap', 'percent': 4.81}, {'genre': 'post-teen pop', 'percent': 4.46}, {'genre': 'contemporary country', 'percent': 3.76}, {'genre': 'country', 'percent': 3.71}, {'genre': 'hip hop', 'percent': 3.58}, {'genre': 'country road', 'percent': 3.58}]}, {'year': 2012, 'genres': [{'genre': 'pop', 'percent': 10.08}, {'genre': 'dance pop', 'percent': 7.71}, {'genre': 'pop rap', 'percent': 7.1}, {'genre': 'pop christmas', 'percent': 5.24}, {'genre': 'rap', 'percent': 5.01}, {'genre': 'post-teen pop', 'percent': 4.36}, {'genre': 'hip hop', 'percent': 3.9}, {'genre': 'contemporary country', 'percent': 3.79}, {'genre': 'country', 'percent': 3.67}, {'genre': 'country road', 'percent': 3.66}]}, {'year': 2013, 'genres': [{'genre': 'pop', 'percent': 9.84}, {'genre': 'dance pop', 'percent': 7.47}, {'genre': 'pop rap', 'percent': 6.44}, {'genre': 'rap', 'percent': 5.43}, {'genre': 'post-teen pop', 'percent': 4.1}, {'genre': 'pop christmas', 'percent': 3.99}, {'genre': 'hip hop', 'percent': 3.93}, {'genre': 'contemporary country', 'percent': 3.93}, {'genre': 'southern hip hop', 'percent': 3.7}, {'genre': 'country road', 'percent': 3.65}]}, {'year': 2014, 'genres': [{'genre': 'pop', 'percent': 11.05}, {'genre': 'dance pop', 'percent': 7.52}, {'genre': 'pop rap', 'percent': 6.52}, {'genre': 'rap', 'percent': 5.13}, {'genre': 'post-teen pop', 'percent': 4.58}, {'genre': 'contemporary country', 'percent': 4.19}, {'genre': 'pop christmas', 'percent': 4.09}, {'genre': 'country road', 'percent': 3.88}, {'genre': 'country', 'percent': 3.83}, {'genre': 'hip hop', 'percent': 3.67}]}, {'year': 2015, 'genres': [{'genre': 'pop', 'percent': 12.54}, {'genre': 'dance pop', 'percent': 8.35}, {'genre': 'pop rap', 'percent': 6.64}, {'genre': 'rap', 'percent': 5.56}, {'genre': 'post-teen pop', 'percent': 5.25}, {'genre': 'contemporary country', 'percent': 3.95}, {'genre': 'pop christmas', 'percent': 3.82}, {'genre': 'trap music', 'percent': 3.61}, {'genre': 'southern hip hop', 'percent': 3.59}, {'genre': 'country road', 'percent': 3.31}]}, {'year': 2016, 'genres': [{'genre': 'pop', 'percent': 13.73}, {'genre': 'dance pop', 'percent': 7.46}, {'genre': 'rap', 'percent': 7.45}, {'genre': 'pop rap', 'percent': 6.89}, {'genre': 'trap music', 'percent': 5.66}, {'genre': 'post-teen pop', 'percent': 5.18}, {'genre': 'southern hip hop', 'percent': 4.29}, {'genre': 'contemporary country', 'percent': 3.75}, {'genre': 'hip hop', 'percent': 3.21}, {'genre': 'country road', 'percent': 2.99}]}, {'year': 2017, 'genres': [{'genre': 'pop', 'percent': 15.77}, {'genre': 'rap', 'percent': 8.95}, {'genre': 'dance pop', 'percent': 6.8}, {'genre': 'pop rap', 'percent': 6.16}, {'genre': 'trap music', 'percent': 6.12}, {'genre': 'post-teen pop', 'percent': 5.2}, {'genre': 'contemporary country', 'percent': 4.11}, {'genre': 'southern hip hop', 'percent': 3.88}, {'genre': 'hip hop', 'percent': 3.6}, {'genre': 'country road', 'percent': 3.24}]}, {'year': 2018, 'genres': [{'genre': 'pop', 'percent': 16.11}, {'genre': 'rap', 'percent': 10.99}, {'genre': 'trap music', 'percent': 8.07}, {'genre': 'dance pop', 'percent': 5.97}, {'genre': 'pop rap', 'percent': 5.46}, {'genre': 'post-teen pop', 'percent': 5.24}, {'genre': 'southern hip hop', 'percent': 4.72}, {'genre': 'contemporary country', 'percent': 3.75}, {'genre': 'hip hop', 'percent': 3.41}, {'genre': 'country road', 'percent': 2.56}]}]

# %%
type(json.loads(json.dumps(test)))
# Out:
# list
